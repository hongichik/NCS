# %%
path_main = "/content/drive/MyDrive/NCS_NEW/NCS/SR-GNN"
path_data = "/content/drive/MyDrive/NCS_NEW/DATA2"

# %%
# !cp -r /content/drive/MyDrive/NCS_NEW/DATA2/SR-GNN/ /content/DATA/

# %%
# %cd /content/drive/MyDrive/NCS_NEW/NCS
# !git fetch --all
# !git reset --hard origin/main
# !git pull
# Out:
# /content/drive/MyDrive/NCS_NEW/NCS
# Fetching origin
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 675 bytes | 8.00 KiB/s, done.
# From github.com:hongichik/NCS
#    cbb2ee6..78ae21c  main       -> origin/main
# Updating files: 100% (202/202), done.
# HEAD is now at 78ae21c update
# Already up to date.

# %%
# !ls
# %cd /content/drive/MyDrive/NCS_NEW/NCS/DHCN
# !ls
# Out:
# DHCN  DuoRec  GCE-GNN  push.sh	README.md  SR-GNN
# /content/drive/MyDrive/NCS_NEW/NCS/DHCN
# main.py  model.py  __pycache__	README.md  util.py

# %%
# Tạo thư mục chứa log
# !mkdir -p /content/drive/MyDrive/NCS_NEW/LOG/DHCP/retailrocket

# %%
# !python main.py \
  --dataset retailrocket \
  --data_path /data/hongnguyen/DATA2/SR-GNN/retailrocket \
  --log /home/hongnguyen/NCS_NEW/LOG/DHCP/retailrocket/retailrocket.log \
  --epoch 1 --batchSize 100 --embSize 100 --l2 1e-05 --lr 0.001 --layer 3 --beta 0.01 --topk '20'
# Out:
# /content/drive/MyDrive/NCS_NEW/NCS/DHCN
# Namespace(dataset='retailrocket', data_path='/content/DATA/retailrocket', epoch=1, batchSize=100, embSize=100, l2=1e-05, lr=0.001, layer=3, beta=0.01, filter=False, n_node=None, log='/content/drive/MyDrive/NCS_NEW/LOG/DHCP/retailrocket/retailrocket.log', topk='20')
# Auto inferred n_node = 60520
# Using device = cuda:0
# -------------------------------------------------------
# epoch:  0
# start training:  2026-04-29 10:58:48.551339
# training batch: 50/10380	loss: 12.0624	it/s: 0.60	eta: 4:45:31
# training batch: 100/10380	loss: 11.7421	it/s: 0.60	eta: 4:46:04
# training batch: 150/10380	loss: 11.4997	it/s: 0.60	eta: 4:43:38
# training batch: 200/10380	loss: 11.3168	it/s: 0.61	eta: 4:39:49
# training batch: 250/10380	loss: 11.1626	it/s: 0.60	eta: 4:39:53
# training batch: 300/10380	loss: 11.0328	it/s: 0.61	eta: 4:37:02
# training batch: 350/10380	loss: 10.9062	it/s: 0.61	eta: 4:33:44
# ...
